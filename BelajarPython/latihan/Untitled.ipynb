# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.arange(1,20,0.5)

# %%
x
# Out:
# array([ 1. ,  1.5,  2. ,  2.5,  3. ,  3.5,  4. ,  4.5,  5. ,  5.5,  6. ,
#         6.5,  7. ,  7.5,  8. ,  8.5,  9. ,  9.5, 10. , 10.5, 11. , 11.5,
#        12. , 12.5, 13. , 13.5, 14. , 14.5, 15. , 15.5, 16. , 16.5, 17. ,
#        17.5, 18. , 18.5, 19. , 19.5])

# %%
y=x**2

# %%
plt.plot(x,y,marker="D", mfc="red", ms="3.2");

# %%
plt.savefig('grrafik.png')

# %%
ls
# Out:
# PackagesUtama/  bari.py      grrafik.png       modulku.py
# Untitled.ipynb  biodata.txt  hitung-zscore.py  programku.py
# __pycache__/    coba.py      latihan-tulis.py  selamat.txt
